# %%
# Import dependencies
import pandas as pd
import numpy as np

# %% [markdown]
# # Import China EIA data

# %%
# Create a DataFrame for China EIA data. 
ChinaEIA_df = pd.read_csv("Resources/ChinaEIA.csv")
ChinaEIA_df.head()
# Out:
#                    Metric                                    Type   1980  \
# 0  INTL.4411-2-CHN-QBTU.A                         Coal (quad Btu)  13.81
# 1  INTL.4413-2-CHN-QBTU.A                  Natural gas (quad Btu)   0.58
# 2  INTL.4415-2-CHN-QBTU.A  Petroleum and other liquids (quad Btu)   4.12
# 3  INTL.4417-2-CHN-QBTU.A                      Nuclear (quad Btu)    NaN
# 4  INTL.4418-2-CHN-QBTU.A         Renewables and other (quad Btu)   0.59
#
#     1981   1982   1983   1984   1985   1986   1987  ...   2010   2011   2012  \
# 0  13.84  14.85  15.92  17.60  18.59  19.14  20.21  ...  81.12  89.38  94.50
# 1   0.52   0.44   0.50   0.50   0.53   0.56   0.57  ...   3.94   4.83   5.30
# 2   3.94   3.89   3.97   4.06   4.29   4.36   4.58  ...  18.69  19.69  20.71
# 3    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...   0.72   0.83   0.94
# 4   0.67   0.76   0.89   0.89   0.95   0.97   1.02  ...   7.51   7.57   9.43
#
#     2013   2014   2015   2016   2017   2018   2019
# ...

# %%
# renaming columns 
ChinaEIA_df.rename(columns= {'Type': "Indicator Name", 
                            'Metric': "Indicator Code"}, inplace = True)
ChinaEIA_df.head()
# Out:
#            Indicator Code                          Indicator Name   1980  \
# 0  INTL.4411-2-CHN-QBTU.A                         Coal (quad Btu)  13.81
# 1  INTL.4413-2-CHN-QBTU.A                  Natural gas (quad Btu)   0.58
# 2  INTL.4415-2-CHN-QBTU.A  Petroleum and other liquids (quad Btu)   4.12
# 3  INTL.4417-2-CHN-QBTU.A                      Nuclear (quad Btu)    NaN
# 4  INTL.4418-2-CHN-QBTU.A         Renewables and other (quad Btu)   0.59
#
#     1981   1982   1983   1984   1985   1986   1987  ...   2010   2011   2012  \
# 0  13.84  14.85  15.92  17.60  18.59  19.14  20.21  ...  81.12  89.38  94.50
# 1   0.52   0.44   0.50   0.50   0.53   0.56   0.57  ...   3.94   4.83   5.30
# 2   3.94   3.89   3.97   4.06   4.29   4.36   4.58  ...  18.69  19.69  20.71
# 3    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...   0.72   0.83   0.94
# 4   0.67   0.76   0.89   0.89   0.95   0.97   1.02  ...   7.51   7.57   9.43
#
#     2013   2014   2015   2016   2017   2018   2019
# ...

# %%
ChinaEIA_df.insert(0, "Country Name", "China")
ChinaEIA_df.head()
# Out:
#   Country Name          Indicator Code  \
# 0        China  INTL.4411-2-CHN-QBTU.A
# 1        China  INTL.4413-2-CHN-QBTU.A
# 2        China  INTL.4415-2-CHN-QBTU.A
# 3        China  INTL.4417-2-CHN-QBTU.A
# 4        China  INTL.4418-2-CHN-QBTU.A
#
#                            Indicator Name   1980   1981   1982   1983   1984  \
# 0                         Coal (quad Btu)  13.81  13.84  14.85  15.92  17.60
# 1                  Natural gas (quad Btu)   0.58   0.52   0.44   0.50   0.50
# 2  Petroleum and other liquids (quad Btu)   4.12   3.94   3.89   3.97   4.06
# 3                      Nuclear (quad Btu)    NaN    NaN    NaN    NaN    NaN
# 4         Renewables and other (quad Btu)   0.59   0.67   0.76   0.89   0.89
#
#     1985   1986  ...   2010   2011   2012   2013   2014   2015   2016   2017  \
# 0  18.59  19.14  ...  81.12  89.38  94.50  96.12  94.46  91.43  89.12  89.37
# 1   0.53   0.56  ...   3.94   4.83   5.30   6.02   6.69   7.04   7.64   8.81
# ...

# %%
ChinaEIA_df.insert(1, "Country Code", "CHN")
ChinaEIA_df.head()
# Out:
#   Country Name Country Code          Indicator Code  \
# 0        China          CHN  INTL.4411-2-CHN-QBTU.A
# 1        China          CHN  INTL.4413-2-CHN-QBTU.A
# 2        China          CHN  INTL.4415-2-CHN-QBTU.A
# 3        China          CHN  INTL.4417-2-CHN-QBTU.A
# 4        China          CHN  INTL.4418-2-CHN-QBTU.A
#
#                            Indicator Name   1980   1981   1982   1983   1984  \
# 0                         Coal (quad Btu)  13.81  13.84  14.85  15.92  17.60
# 1                  Natural gas (quad Btu)   0.58   0.52   0.44   0.50   0.50
# 2  Petroleum and other liquids (quad Btu)   4.12   3.94   3.89   3.97   4.06
# 3                      Nuclear (quad Btu)    NaN    NaN    NaN    NaN    NaN
# 4         Renewables and other (quad Btu)   0.59   0.67   0.76   0.89   0.89
#
#     1985  ...   2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# 0  18.59  ...  81.12  89.38  94.50  96.12  94.46  91.43  89.12  89.37  90.37
# ...

# %% [markdown]
# # Create Dataframes for Independent Variables

# %%
# Create a DataFrame for global GDP data. 
globalgdp_df = pd.read_csv("Resources/gdp.csv")
globalgdp_df.head()
# Out:
#                   Country Name Country Code         Indicator Name  \
# 0                        Aruba          ABW  GDP growth (annual %)
# 1  Africa Eastern and Southern          AFE  GDP growth (annual %)
# 2                  Afghanistan          AFG  GDP growth (annual %)
# 3   Africa Western and Central          AFW  GDP growth (annual %)
# 4                       Angola          AGO  GDP growth (annual %)
#
#       Indicator Code  1960      1961      1962      1963      1964      1965  \
# 0  NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
# 1  NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
# 2  NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
# 3  NY.GDP.MKTP.KD.ZG   NaN  1.848719  3.770212  7.272501  5.396356  4.049794
# 4  NY.GDP.MKTP.KD.ZG   NaN       NaN       NaN       NaN       NaN       NaN
#
#    ...      2011       2012      2013      2014      2015      2016      2017  \
# ...

# %%
# Create a DataFrame for global population data. 
globalpopulation_df = pd.read_csv("Resources/population.csv")
globalpopulation_df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965  ...         2011         2012         2013         2014  \
# ...

# %%
# Create a DataFrame for global urbanization data. 
globalurbanization_df = pd.read_csv("Resources/urbanization.csv")
globalurbanization_df.head()
# Out:
#                   Country Name Country Code    Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Urban population    SP.URB.TOTL
# 1  Africa Eastern and Southern          AFE  Urban population    SP.URB.TOTL
# 2                  Afghanistan          AFG  Urban population    SP.URB.TOTL
# 3   Africa Western and Central          AFW  Urban population    SP.URB.TOTL
# 4                       Angola          AGO  Urban population    SP.URB.TOTL
#
#          1960        1961        1962        1963        1964        1965  \
# 0     27525.0     28139.0     28537.0     28763.0     28922.0     29080.0
# 1  19239140.0  20049454.0  20897622.0  21807831.0  22780115.0  23806156.0
# 2    755835.0    796271.0    839385.0    885227.0    934134.0    986074.0
# 3  14141671.0  14813809.0  15527606.0  16290977.0  17102150.0  17961784.0
# 4    569223.0    597286.0    628376.0    660175.0    691526.0    721552.0
#
# ...

# %%
# Extract china gdp from global gdp dataframe using loc method. 
chinagdp_df = globalgdp_df.loc[globalgdp_df['Country Name']=="China"]
chinagdp_df.head()
# Out:
#    Country Name Country Code         Indicator Name     Indicator Code  1960  \
# 40        China          CHN  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
#
#      1961  1962  1963   1964   1965  ...      2011      2012     2013  \
# 40 -27.27 -5.58  10.3  18.18  16.95  ...  9.550832  7.863736  7.76615
#
#         2014      2015      2016      2017      2018      2019      2020
# 40  7.425764  7.041329  6.848762  6.947201  6.749774  5.949714  2.347514
#
# [1 rows x 65 columns]

# %%
# Extract India gdp from global gdp dataframe using loc method. 
indiagdp_df = globalgdp_df.loc[globalgdp_df['Country Name']=="India"]
indiagdp_df.head()
# Out:
#     Country Name Country Code         Indicator Name     Indicator Code  1960  \
# 109        India          IND  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
#
#          1961      1962      1963     1964     1965  ...      2011      2012  \
# 109  3.722743  2.931128  5.994353  7.45295 -2.63577  ...  5.241315  5.456389
#
#          2013      2014      2015      2016      2017      2018      2019  \
# 109  6.386106  7.410228  7.996254  8.256306  6.795383  6.532989  4.041554
#
#          2020
# 109 -7.251755
#
# [1 rows x 65 columns]

# %%
# Extract china population from global population dataframe using loc method. 
chinapopulation_df = globalpopulation_df.loc[globalgdp_df['Country Name']=="China"]
chinapopulation_df.head()
# Out:
#    Country Name Country Code     Indicator Name Indicator Code         1960  \
# 40        China          CHN  Population, total    SP.POP.TOTL  667070000.0
#
#            1961         1962         1963         1964         1965  ...  \
# 40  660330000.0  665770000.0  682335000.0  698355000.0  715185000.0  ...
#
#             2011          2012          2013          2014          2015  \
# 40  1.345035e+09  1.354190e+09  1.363240e+09  1.371860e+09  1.379860e+09
#
#             2016          2017          2018          2019          2020
# 40  1.387790e+09  1.396215e+09  1.402760e+09  1.407745e+09  1.410929e+09
#
# [1 rows x 65 columns]

# %%
# Extract India population from global population dataframe using loc method. 
indiapopulation_df = globalpopulation_df.loc[globalgdp_df['Country Name']=="India"]
indiapopulation_df.head()
# Out:
#     Country Name Country Code     Indicator Name Indicator Code         1960  \
# 109        India          IND  Population, total    SP.POP.TOTL  450547675.0
#
#             1961         1962         1963         1964         1965  ...  \
# 109  459642166.0  469077191.0  478825602.0  488848139.0  499123328.0  ...
#
#              2011          2012          2013          2014          2015  \
# 109  1.250288e+09  1.265780e+09  1.280842e+09  1.295601e+09  1.310152e+09
#
#              2016          2017          2018          2019          2020
# 109  1.324517e+09  1.338677e+09  1.352642e+09  1.366418e+09  1.380004e+09
#
# [1 rows x 65 columns]

# %%
# Extract china urbanization from global urbanization dataframe using loc method.  
chinaurbanization_df = globalurbanization_df.loc[globalgdp_df['Country Name']=="China"]
chinaurbanization_df.head()
# Out:
#    Country Name Country Code    Indicator Name Indicator Code         1960  \
# 40        China          CHN  Urban population    SP.URB.TOTL  108085352.0
#
#            1961         1962         1963         1964         1965  ...  \
# 40  110327936.0  114685540.0  121162226.0  127791981.0  129348359.0  ...
#
#            2011         2012         2013         2014         2015  \
# 40  679390629.0  700996454.0  722694421.0  744357517.0  765822300.0
#
#            2016         2017         2018         2019         2020
# 40  787376534.0  809246214.0  829760595.0  848982855.0  866705688.0
#
# [1 rows x 65 columns]

# %%
# Extract india urbanization from global urbanization dataframe using loc method.  
indiaurbanization_df = globalurbanization_df.loc[globalgdp_df['Country Name']=="India"]
indiaurbanization_df.head()
# Out:
#     Country Name Country Code    Indicator Name Indicator Code        1960  \
# 109        India          IND  Urban population    SP.URB.TOTL  80756165.0
#
#            1961        1962        1963        1964        1965  ...  \
# 109  82882675.0  85456483.0  88127852.0  90901311.0  93760317.0  ...
#
#             2011         2012         2013         2014         2015  \
# 109  391040056.0  400416922.0  409907903.0  419567353.0  429428650.0
#
#             2016         2017         2018         2019         2020
# 109  439501314.0  449795398.0  460304169.0  471031529.0  481980332.0
#
# [1 rows x 65 columns]

# %%
# Concatenate china dataframes into single dataframe.  
# Our initial code is below; I refractored into cleaner code which is found in a later part of the code. -AMH    
    # chinadata_df = chinagdp_df.append(chinapopulation_df)
    # chinadata_df = chinadata_df.append(chinaurbanization_df)
    # chinadata_df.head()
    
    # alldata_df = pd.concat([chinagdp_df, chinapopulation_df, chinaurbanization_df, chinaelectricity_df], sort=False)

# %% [markdown]
# # Create Dataframes for Dependent Variables

# %%
# Create a DataFrame for global DDP data. 
globalelectricity_df = pd.read_csv("Resources\electricity-generation.csv")
globalelectricity_df["Indicator Name"] = "Electricity"
globalelectricity_df.head()
# Out:
#      Country Name     1985     1986     1987     1988     1989     1990  \
# 0     Afghanistan      NaN      NaN      NaN      NaN      NaN      NaN
# 1          Africa  258.986  270.110  280.260  295.296  306.648  318.921
# 2         Albania      NaN      NaN      NaN      NaN      NaN    3.300
# 3         Algeria   12.274   12.981   12.722   13.966   15.324   16.104
# 4  American Samoa      NaN      NaN      NaN      NaN      NaN      NaN
#
#       1991     1992     1993  ...     2015     2016     2017     2018  \
# 0      NaN      NaN      NaN  ...    1.178    1.210    1.256    1.115
# 1  324.998  328.020  339.205  ...  787.381  802.473  828.095  845.795
# 2    3.820    3.400    3.530  ...    5.890    7.780    4.520    8.550
# 3   17.345   18.286   19.414  ...   64.682   66.755   71.495   72.057
# 4      NaN      NaN      NaN  ...    0.163    0.170    0.167    0.163
#
#       2019  2020  2021  (blank)  Grand Total  Indicator Name
# ...

# %%
# Extract china gdp from global gdp dataframe using loc method.  
chinaelectricity_df = globalelectricity_df.loc[globalelectricity_df['Country Name']=="China"]
chinaelectricity_df.head()
# Out:
#    Country Name    1985    1986     1987    1988    1989   1990    1991  \
# 42        China  410.69  449.53  497.267  545.21  584.81  621.2  677.55
#
#       1992    1993  ...    2015    2016    2017    2018    2019      2020  \
# 42  753.94  811.59  ...  5740.0  6022.8  6448.7  6996.2  7326.7  7623.696
#
#     2021  (blank)  Grand Total  Indicator Name
# 42   NaN      NaN   100948.025     Electricity
#
# [1 rows x 41 columns]

# %%
# Extract India gdp from global gdp dataframe using loc method.  
indiaelectricity_df = globalelectricity_df.loc[globalelectricity_df['Country Name']=="India"]
indiaelectricity_df.head()
# Out:
#    Country Name     1985     1986     1987     1988     1989     1990  \
# 95        India  186.386  202.677  223.669  241.305  272.446  287.763
#
#        1991     1992     1993  ...      2015      2016      2017      2018  \
# 95  320.458  337.153  362.176  ...  1139.551  1224.126  1285.739  1367.832
#
#         2019      2020  2021  (blank)  Grand Total  Indicator Name
# 95  1378.174  1341.967   NaN      NaN    23869.113     Electricity
#
# [1 rows x 41 columns]

# %% [markdown]
# # Merge Dependent and Independent Variables

# %%
# Concatenate china dataframes into single dataframe
alldata_df = pd.concat([chinagdp_df, chinapopulation_df, chinaurbanization_df, chinaelectricity_df, ChinaEIA_df], sort=False)
alldata_df
# Out:
#    Country Name Country Code                          Indicator Name  \
# 40        China          CHN                   GDP growth (annual %)
# 40        China          CHN                       Population, total
# 40        China          CHN                        Urban population
# 42        China          NaN                             Electricity
# 0         China          CHN                         Coal (quad Btu)
# 1         China          CHN                  Natural gas (quad Btu)
# 2         China          CHN  Petroleum and other liquids (quad Btu)
# 3         China          CHN                      Nuclear (quad Btu)
# 4         China          CHN         Renewables and other (quad Btu)
#
#             Indicator Code         1960          1961          1962  \
# 40       NY.GDP.MKTP.KD.ZG          NaN -2.727000e+01 -5.580000e+00
# 40             SP.POP.TOTL  667070000.0  6.603300e+08  6.657700e+08
# 40             SP.URB.TOTL  108085352.0  1.103279e+08  1.146855e+08
# ...

# %%
# Concatenate china dataframes into single dataframe
allindiadata_df = pd.concat([indiagdp_df, indiapopulation_df, indiaurbanization_df, indiaelectricity_df], sort=False)
allindiadata_df
# Out:
#     Country Name Country Code         Indicator Name     Indicator Code  \
# 109        India          IND  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 109        India          IND      Population, total        SP.POP.TOTL
# 109        India          IND       Urban population        SP.URB.TOTL
# 95         India          NaN            Electricity                NaN
#
#             1960          1961          1962          1963          1964  \
# 109          NaN  3.722743e+00  2.931128e+00  5.994353e+00  7.452950e+00
# 109  450547675.0  4.596422e+08  4.690772e+08  4.788256e+08  4.888481e+08
# 109   80756165.0  8.288268e+07  8.545648e+07  8.812785e+07  9.090131e+07
# 95           NaN           NaN           NaN           NaN           NaN
#
#              1965  ...          2014          2015          2016  \
# 109 -2.635770e+00  ...  7.410228e+00  7.996254e+00  8.256306e+00
# 109  4.991233e+08  ...  1.295601e+09  1.310152e+09  1.324517e+09
# ...

# %%
# Select only columns where we have all data
# df.drop(df.loc[:, 'B':'D'].columns, axis = 1)
# I refractored this code on 3/8.  Previous code below.  -AMH 
    # alldata19852020_df = alldata_df.drop(alldata_df.loc[:, 'Indicator Code':'1984'].columns, axis =1)
    # alldatadropcolumns_df = alldata19852020_df.drop(alldata19852020_df.loc[:, 'Country Name':'Country Code'].columns, axis =1)
    # alldataclean_df = alldatadropcolumns_df.drop(alldatadropcolumns_df.loc[:, '2020':'Grand Total'].columns, axis =1)
    # alldataclean_df.head() 

alldataclean_df = alldata_df \
    .drop(alldata_df.loc[:, 'Indicator Code':'1984'].columns, axis =1) \
    .drop(alldata_df.loc[:, 'Country Name':'Country Code'].columns, axis =1) \
    .drop(alldata_df.loc[:, '2020':'Grand Total'].columns, axis =1)
alldataclean_df
# Out:
#                             Indicator Name          1985          1986  \
# 40                   GDP growth (annual %)  1.343068e+01  8.949962e+00
# 40                       Population, total  1.051040e+09  1.066790e+09
# 40                        Urban population  2.404149e+08  2.513251e+08
# 42                             Electricity  4.106900e+02  4.495300e+02
# 0                          Coal (quad Btu)  1.859000e+01  1.914000e+01
# 1                   Natural gas (quad Btu)  5.300000e-01  5.600000e-01
# 2   Petroleum and other liquids (quad Btu)  4.290000e+00  4.360000e+00
# 3                       Nuclear (quad Btu)           NaN           NaN
# 4          Renewables and other (quad Btu)  9.500000e-01  9.700000e-01
#
#             1987          1988          1989          1990          1991  \
# 40  1.165743e+01  1.122259e+01  4.206334e+00  3.920251e+00  9.262786e+00
# 40  1.084035e+09  1.101630e+09  1.118650e+09  1.135185e+09  1.150780e+09
# ...

# %%
allindiadataclean_df = allindiadata_df \
    .drop(allindiadata_df.loc[:, 'Indicator Code':'1984'].columns, axis =1) \
    .drop(allindiadata_df.loc[:, 'Country Name':'Country Code'].columns, axis =1) \
    .drop(allindiadata_df.loc[:, '2020':'Grand Total'].columns, axis =1)
allindiadataclean_df.head()
# Out:
#             Indicator Name          1985          1986          1987  \
# 109  GDP growth (annual %)  5.254299e+00  4.776564e+00  3.965356e+00
# 109      Population, total  7.843600e+08  8.019752e+08  8.196821e+08
# 109       Urban population  1.909760e+08  1.971656e+08  2.034697e+08
# 95             Electricity  1.863860e+02  2.026770e+02  2.236690e+02
#
#              1988          1989          1990          1991          1992  \
# 109  9.627783e+00  5.947343e+00  5.533455e+00  1.056831e+00  5.482396e+00
# 109  8.374689e+08  8.553347e+08  8.732778e+08  8.912732e+08  9.093070e+08
# 109  2.098948e+08  2.164424e+08  2.230963e+08  2.297524e+08  2.362743e+08
# 95   2.413050e+02  2.724460e+02  2.877630e+02  3.204580e+02  3.371530e+02
#
#              1993  ...          2010          2011          2012  \
# 109  4.750776e+00  ...  8.497585e+00  5.241315e+00  5.456389e+00
# 109  9.274039e+08  ...  1.234281e+09  1.250288e+09  1.265780e+09
# ...

# %%
# Transpose clean dataframs for machine learning model
alldataclean_transpose_df = alldataclean_df.T
alldataclean_transpose_df.head()
# Out:
#                                    40                 40                40  \
# Indicator Name  GDP growth (annual %)  Population, total  Urban population
# 1985                        13.430678       1051040000.0       240414890.0
# 1986                         8.949962       1066790000.0       251325056.0
# 1987                        11.657428       1084035000.0       262976051.0
# 1988                        11.222595       1101630000.0       275121076.0
#
#                          42               0                       1   \
# Indicator Name  Electricity  Coal (quad Btu)  Natural gas (quad Btu)
# 1985                 410.69            18.59                    0.53
# 1986                 449.53            19.14                    0.56
# 1987                497.267            20.21                    0.57
# 1988                 545.21             21.6                    0.58
#
#                                                     2                   3   \
# ...

# %%
# Transpose clean dataframs for machine learning model
allindiadataclean_transpose_df = allindiadataclean_df.T
allindiadataclean_transpose_df.head()
# Out:
#                                   109                109               109  \
# Indicator Name  GDP growth (annual %)  Population, total  Urban population
# 1985                         5.254299        784360012.0       190975976.0
# 1986                         4.776564        801975250.0       197165615.0
# 1987                         3.965356        819682095.0       203469686.0
# 1988                         9.627783        837468938.0       209894840.0
#
#                         95
# Indicator Name  Electricity
# 1985                186.386
# 1986                202.677
# 1987                223.669
# 1988                241.305

# %%
# Create header row
#new_header_df = alldataclean_transpose_df.copy()
alldataclean_transpose_df.columns = alldataclean_transpose_df.iloc[0] 
alldataclean_transpose_df = alldataclean_transpose_df[1:].reset_index()
alldataclean_transpose_df.head()
# Out:
# Indicator Name index GDP growth (annual %) Population, total Urban population  \
# 0               1985             13.430678      1051040000.0      240414890.0
# 1               1986              8.949962      1066790000.0      251325056.0
# 2               1987             11.657428      1084035000.0      262976051.0
# 3               1988             11.222595      1101630000.0      275121076.0
# 4               1989              4.206334      1118650000.0      287504237.0
#
# Indicator Name Electricity Coal (quad Btu) Natural gas (quad Btu)  \
# 0                   410.69           18.59                   0.53
# 1                   449.53           19.14                   0.56
# 2                  497.267           20.21                   0.57
# 3                   545.21            21.6                   0.58
# 4                   584.81           21.46                   0.58
#
# Indicator Name Petroleum and other liquids (quad Btu) Nuclear (quad Btu)  \
# ...

# %%
# Create header row
#new_header_df = alldataclean_transpose_df.copy()
allindiadataclean_transpose_df.columns = allindiadataclean_transpose_df.iloc[0] 
allindiadataclean_transpose_df = allindiadataclean_transpose_df[1:].reset_index()
allindiadataclean_transpose_df.head()
# Out:
# Indicator Name index GDP growth (annual %) Population, total Urban population  \
# 0               1985              5.254299       784360012.0      190975976.0
# 1               1986              4.776564       801975250.0      197165615.0
# 2               1987              3.965356       819682095.0      203469686.0
# 3               1988              9.627783       837468938.0      209894840.0
# 4               1989              5.947343       855334675.0      216442440.0
#
# Indicator Name Electricity
# 0                  186.386
# 1                  202.677
# 2                  223.669
# 3                  241.305
# 4                  272.446

# %%
# renaming columns 
alldataclean_transpose_df.rename(columns= {'index': "Year",
                                           "Population, total": "Total Population (persons)"}, inplace = True)
alldataclean_transpose_df.head()
# Out:
# Indicator Name  Year GDP growth (annual %) Total Population (persons)  \
# 0               1985             13.430678               1051040000.0
# 1               1986              8.949962               1066790000.0
# 2               1987             11.657428               1084035000.0
# 3               1988             11.222595               1101630000.0
# 4               1989              4.206334               1118650000.0
#
# Indicator Name Urban population Electricity Coal (quad Btu)  \
# 0                   240414890.0      410.69           18.59
# 1                   251325056.0      449.53           19.14
# 2                   262976051.0     497.267           20.21
# 3                   275121076.0      545.21            21.6
# 4                   287504237.0      584.81           21.46
#
# Indicator Name Natural gas (quad Btu) Petroleum and other liquids (quad Btu)  \
# 0                                0.53                                   4.29
# ...

# %%
# renaming columns 
allindiadataclean_transpose_df.rename(columns= {'index': "Year",
                                           "Population, total": "Total Population (persons)"}, inplace = True)
allindiadataclean_transpose_df.head()
# Out:
# Indicator Name  Year GDP growth (annual %) Total Population (persons)  \
# 0               1985              5.254299                784360012.0
# 1               1986              4.776564                801975250.0
# 2               1987              3.965356                819682095.0
# 3               1988              9.627783                837468938.0
# 4               1989              5.947343                855334675.0
#
# Indicator Name Urban population Electricity
# 0                   190975976.0     186.386
# 1                   197165615.0     202.677
# 2                   203469686.0     223.669
# 3                   209894840.0     241.305
# 4                   216442440.0     272.446

# %%
alldataclean_transpose_df.rename_axis(None, axis =1)
alldataclean_transpose_df.head()
# Out:
# Indicator Name  Year GDP growth (annual %) Total Population (persons)  \
# 0               1985             13.430678               1051040000.0
# 1               1986              8.949962               1066790000.0
# 2               1987             11.657428               1084035000.0
# 3               1988             11.222595               1101630000.0
# 4               1989              4.206334               1118650000.0
#
# Indicator Name Urban population Electricity Coal (quad Btu)  \
# 0                   240414890.0      410.69           18.59
# 1                   251325056.0      449.53           19.14
# 2                   262976051.0     497.267           20.21
# 3                   275121076.0      545.21            21.6
# 4                   287504237.0      584.81           21.46
#
# Indicator Name Natural gas (quad Btu) Petroleum and other liquids (quad Btu)  \
# 0                                0.53                                   4.29
# ...

# %%
allindiadataclean_transpose_df.rename_axis(None, axis =1)
allindiadataclean_transpose_df.head()
# Out:
# Indicator Name  Year GDP growth (annual %) Total Population (persons)  \
# 0               1985              5.254299                784360012.0
# 1               1986              4.776564                801975250.0
# 2               1987              3.965356                819682095.0
# 3               1988              9.627783                837468938.0
# 4               1989              5.947343                855334675.0
#
# Indicator Name Urban population Electricity
# 0                   190975976.0     186.386
# 1                   197165615.0     202.677
# 2                   203469686.0     223.669
# 3                   209894840.0     241.305
# 4                   216442440.0     272.446

# %% [markdown]
# # Import Dependencies for China Machine Learning Model

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = alldataclean_transpose_df
df.head()
# Out:
# Indicator Name  Year GDP growth (annual %) Total Population (persons)  \
# 0               1985             13.430678               1051040000.0
# 1               1986              8.949962               1066790000.0
# 2               1987             11.657428               1084035000.0
# 3               1988             11.222595               1101630000.0
# 4               1989              4.206334               1118650000.0
#
# Indicator Name Urban population Electricity Coal (quad Btu)  \
# 0                   240414890.0      410.69           18.59
# 1                   251325056.0      449.53           19.14
# 2                   262976051.0     497.267           20.21
# 3                   275121076.0      545.21            21.6
# 4                   287504237.0      584.81           21.46
#
# Indicator Name Natural gas (quad Btu) Petroleum and other liquids (quad Btu)  \
# 0                                0.53                                   4.29
# ...

# %%
# plot relationship between GDP and electricity
plt.scatter(df["GDP growth (annual %)"], df.Electricity)
plt.xlabel('GDP growth (annual %)')
plt.ylabel('Electricity')
plt.show()

# %%
# plot relationship between total population and electricity
plt.scatter(df["Total Population (persons)"], df.Electricity)
plt.xlabel('Total Population (persons)')
plt.ylabel('Electricity')
plt.show()

# %%
# plot relationship between urban population and electricity
plt.scatter(df["Urban population"], df.Electricity)
plt.xlabel('Urban population')
plt.ylabel('Electricity')
plt.show()

# %%
# plot relationship between GDP and Coal (quad Btu)
plt.scatter(df["GDP growth (annual %)"], df["Coal (quad Btu)"])
plt.xlabel('GDP growth (annual %)')
plt.ylabel('Coal (quad Btu)')
plt.show()

# %%
# plot relationship between Total Population and Coal (quad Btu)
plt.scatter(df["Total Population (persons)"], df["Coal (quad Btu)"])
plt.xlabel('Total Population (persons)')
plt.ylabel('Coal (quad Btu)')
plt.show()

# %%
# plot relationship between Urban Population and Coal (quad Btu)
plt.scatter(df["Urban population"], df["Coal (quad Btu)"])
plt.xlabel('Urban Population')
plt.ylabel('Coal (quad Btu)')
plt.show()

# %%
# plot relationship between GDP and Natural gas (quad Btu)
plt.scatter(df["GDP growth (annual %)"], df["Natural gas (quad Btu)"])
plt.xlabel('GDP growth (annual %)')
plt.ylabel('Coal (quad Btu)')
plt.show()

# %%
# plot relationship between Total Population and Natural gas (quad Btu)
plt.scatter(df["Total Population (persons)"], df["Natural gas (quad Btu)"])
plt.xlabel('Total Population (persons)')
plt.ylabel('Coal (quad Btu)')
plt.show()

# %%
# plot relationship between Urban Population and Natural gas (quad Btu)
plt.scatter(df["Urban population"], df["Natural gas (quad Btu)"])
plt.xlabel('Urban Population')
plt.ylabel('Coal (quad Btu)')
plt.show()

# %%
# plot relationship between GDP and Petroleum and other liquids (quad Btu)
plt.scatter(df["GDP growth (annual %)"], df["Petroleum and other liquids (quad Btu)"])
plt.xlabel('GDP growth (annual %)')
plt.ylabel('Coal (quad Btu)')
plt.show()

# %%
# plot relationship between Total Population and Petroleum and other liquids (quad Btu)
plt.scatter(df["Total Population (persons)"], df["Petroleum and other liquids (quad Btu)"])
plt.xlabel('Total Population (persons)')
plt.ylabel('Coal (quad Btu)')
plt.show()

# %%
# plot relationship between Urban Population and Petroleum and other liquids (quad Btu)
plt.scatter(df["Urban population"], df["Petroleum and other liquids (quad Btu)"])
plt.xlabel('Urban Population')
plt.ylabel('Coal (quad Btu)')
plt.show()

# %%
# plot relationship between GDP and Renewables and other (quad Btu)
plt.scatter(df["GDP growth (annual %)"], df["Renewables and other (quad Btu)"])
plt.xlabel('GDP growth (annual %)')
plt.ylabel('Coal (quad Btu)')
plt.show()

# %%
# plot relationship between Total Population and Renewables and other (quad Btu)
plt.scatter(df["Total Population (persons)"], df["Renewables and other (quad Btu)"])
plt.xlabel('Total Population (persons)')
plt.ylabel('Coal (quad Btu)')
plt.show()

# %%
# plot relationship between Urban Population and Renewables and other (quad Btu)
plt.scatter(df["Urban population"], df["Renewables and other (quad Btu)"])
plt.xlabel('Urban Population')
plt.ylabel('Coal (quad Btu)')
plt.show()

# %%
# plot relationship between GDP and Nuclear (quad Btu)
plt.scatter(df["GDP growth (annual %)"], df["Nuclear (quad Btu)"])
plt.xlabel('GDP growth (annual %)')
plt.ylabel('Coal (quad Btu)')
plt.show()

# %%
# plot relationship between Total Population and Nuclear (quad Btu)
plt.scatter(df["Total Population (persons)"], df["Nuclear (quad Btu)"])
plt.xlabel('Total Population (persons)')
plt.ylabel('Coal (quad Btu)')
plt.show()

# %%
# plot relationship between Urban Population and Nuclear (quad Btu)
plt.scatter(df["Urban population"], df["Nuclear (quad Btu)"])
plt.xlabel('Urban Population')
plt.ylabel('Coal (quad Btu)')
plt.show()

# %%
X = df["Urban population"].values.reshape(-1, 1)
y = df.Electricity
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (35,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
#print model coef and intercept
print(model.coef_)
print(model.intercept_)
# Out:
# [1.13173609e-05]
# -3145.306482206225
